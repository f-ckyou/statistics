# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 📘 What is Data Visualization in Statistics?
#
# **Data visualization** is the graphical representation of information and data. It helps you to:
# - Understand patterns
# - Spot outliers
# - Communicate findings clearly
# - Simplify complex data
#
# ---
#
# ## 🧰 Why Use It?
#
# | Purpose                      | Example                              |
# |-----------------------------|--------------------------------------|
# | Compare data                | Bar chart for male vs female count   |
# | Show trends over time       | Line chart of stock prices           |
# | Show data distribution      | Histogram, box plot                  |
# | Spot relationships          | Scatter plot                         |
#
# ---
#
# ## 🧱 Types of Statistical Graphs
#
# Let’s cover the **most common** and useful ones with examples:
#
# | Type             | Purpose                               |
# |------------------|----------------------------------------|
# | Bar Chart        | Compare categories                     |
# | Histogram        | Understand frequency distribution      |
# | Pie Chart        | Show proportions                       |
# | Box Plot         | Summarize data with 5-number summary   |
# | Line Chart       | Show trend over time                   |
# | Scatter Plot     | Explore relationships between variables|

# %%
# BAR CHART
    # used for categorical data

categories = ['A', 'B', 'C']
values = [10, 24, 36]

plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Category")
plt.ylabel("Values")
plt.show()

# %%
# HISTOGRAM
    # used for continuous numerical data to show distribution

data = [13, 14, 15, 14, 13, 16, 18, 19, 17, 20, 21, 22]
plt.hist(data, bins=5, color='skyblue', edgecolor='black')
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# PIE CHART
    # shows percentage/proportional data

labels = ['Apple', 'Banana', 'Cherry']
sizes = [30, 45, 25]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Pie Chart Example")
plt.show()

# %%
# BOX PLOT (BOX-and-WHISKER PLOT)
    # used to show 5-number summary: Min, Q1, Median, Q3, Max

data = [10, 12, 13, 15, 17, 18, 19, 21, 22, 23]
plt.boxplot(data)
plt.title("Box Plot Example")
plt.ylabel("Values")
plt.show()

# %%
# LINE CHART
    # best for trends over time

years = [2018, 2019, 2020, 2021]
sales = [100, 150, 200, 250]

plt.plot(years, sales, marker='o')
plt.title("Sales Over Time")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
# SCATTER PLOT
    # used to show correlation or relationship between two variables

x = [1, 2, 3, 4, 5]
y = [5, 7, 9, 10, 15]

plt.scatter(x, y, color='purple')
plt.title("Scatter Plot Example")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## 🧠 Summary Table
#
# | Visualization | Best For                        |
# |---------------|----------------------------------|
# | Bar Chart     | Comparing categories             |
# | Histogram     | Frequency of numerical data      |
# | Pie Chart     | Proportions/percentages          |
# | Box Plot      | Spread and outliers              |
# | Line Chart    | Trend over time                  |
# | Scatter Plot  | Relationships/correlations       |

# %% [markdown]
# ## 🎨 Types of Data Visualization in Statistics (With Examples)
#
# We can broadly classify them into the following categories:
#
# ---
#
# ### 🟦 **1. Univariate Visualizations**
# Visualizing a **single variable** — helps to understand **distribution**, **central tendency**, or **spread**.
#
# | Type        | Purpose                       | Example                              |
# |-------------|-------------------------------|--------------------------------------|
# | Histogram   | Frequency of numerical data   | Height of students                   |
# | Bar Chart   | Count of categories           | No. of students in each grade        |
# | Pie Chart   | Proportions or percentages    | % of different blood groups          |
# | Box Plot    | Spread and outliers           | Distribution of test scores          |
# | Line Plot (Time series) | Change over time         | Temperature over days                |
#
# ---
#
# ### 🟨 **2. Bivariate Visualizations**
# Visualizing **two variables** — helps identify **relationships** or **comparisons**.
#
# | Type         | Purpose                               | Example                          |
# |--------------|----------------------------------------|----------------------------------|
# | Scatter Plot | Relationship between variables         | Age vs Salary                    |
# | Line Graph   | Trend of two variables over time       | Sales vs Months                  |
# | Grouped Bar  | Compare values between subgroups       | Male vs Female across grades     |
# | Hexbin Plot  | Density-based scatter alternative      | Large datasets with overlap      |
#
# ---
#
# ### 🟩 **3. Multivariate Visualizations**
# Visualize **three or more variables** — often uses **color**, **size**, or **position** to represent multiple dimensions.
#
# | Type           | Purpose                                      | Example                             |
# |----------------|-----------------------------------------------|-------------------------------------|
# | Bubble Chart   | Like scatter plot + size                     | Revenue vs Profit vs Investment     |
# | Heatmap        | Color-coded matrix                           | Correlation matrix between variables|
# | Pair Plot      | Grid of scatter plots for many variables     | Full dataset exploration (Seaborn)  |
# | 3D Plot        | Visualize 3D data                            | x, y, z values in physics simulation|
#
# ---
#
# ### 🟥 **4. Statistical Summary Charts**
# To summarize statistics (like distribution, quartiles, outliers).
#
# | Type        | Purpose                           | Example                          |
# |-------------|------------------------------------|----------------------------------|
# | Box Plot    | 5-number summary                   | Exam score spread                |
# | Violin Plot | Distribution + density             | Gender-wise income distribution  |
# | ECDF Plot   | Empirical cumulative distribution  | Cumulative rainfall over days    |
#
# ---
#
# ### 🟫 **5. Distribution & Density Visuals**
# Show how data is spread or distributed.
#
# | Type             | Purpose                           | Example                          |
# |------------------|------------------------------------|----------------------------------|
# | Histogram        | Frequency of values                | Marks distribution               |
# | KDE Plot         | Smoothed density curve             | Income density in population     |
# | Rug Plot         | Small lines for data positions     | Adds data points on axes         |
#
# ---
#
# ### 🟪 **6. Advanced/Interactive Visualizations**
# Used for dashboards and complex datasets.
#
# | Type           | Tool         | Description                           |
# |----------------|--------------|----------------------------------------|
# | Treemap        | Plotly/D3.js | Hierarchical proportion display        |
# | Sunburst Chart | Plotly       | Multilevel pie-like chart              |
# | Choropleth     | Plotly/GeoPandas | Geographic data (maps)            |
# | Interactive Dashboards | Dash/Streamlit | For live visual reports     |
#
# ---
#
# ## 🧭 When to Use Which?
#
# | Goal                         | Recommended Chart      |
# |------------------------------|------------------------|
# | Show composition             | Pie chart, Donut chart |
# | Show distribution            | Histogram, KDE, Box    |
# | Compare values               | Bar chart, Line plot   |
# | Show relationship            | Scatter, Heatmap       |
# | Explore multiple variables   | Pair plot, Bubble      |
# | Show part of whole           | Pie, Treemap           |
#
# ---
#
# ## 📦 Tools/Libraries You Can Use
#
# | Library      | Use Case                             |
# |--------------|--------------------------------------|
# | Matplotlib   | Basic plots (line, bar, hist, etc.)  |
# | Seaborn      | Statistical and beautiful plots      |
# | Plotly       | Interactive charts and dashboards    |
# | Pandas       | Quick plots via `.plot()`            |
# | Altair       | Declarative statistical visualizations|
# | Bokeh        | Browser-based interactive plots      |
#
# ---
#
# ## ✅ Summary
#
# Data visualization types in statistics can be grouped as:
#
# 1. **Univariate** – One variable
# 2. **Bivariate** – Two variables
# 3. **Multivariate** – 3+ variables
# 4. **Statistical Summaries** – Box, Violin, etc.
# 5. **Distribution** – Histogram, KDE, Rug
# 6. **Advanced** – Treemap, Sunburst, Interactive dashboards
